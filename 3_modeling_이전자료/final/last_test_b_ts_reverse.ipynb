# %% [markdown]
# # last_test_b — two_stage_reverse 전체 HPO + 다양성 axes (PC2, ~18시간)
#
# **목적**: 11-base stacking plateau (val=0.005701) 깰 수 있는 신규 다양성 base를 two_stage_reverse(path B) 아키텍처에서 탐색.
#
# **탐색 axes (15축)**:
# - LGBM HP 11종 (회귀·분류 공유)
# - `w0` (y=0 die weight) — log float [0.05, 1.0]
# - `reg_objective` ∈ {regression, poisson, tweedie_1.2, 1.3, 1.5, 1.7, 1.8} — 7종 (확장)
# - `clf_scale_pos_weight` ∈ {1.0, 1.5, 2.43, 3.5} — 4종
# - `feat_subset` ∈ {full, top_300, top_200, top_100} — 4종 (확장)
#
# **알고리즘**: Optuna TPE (n_startup_trials=20). path B는 reg+clf 2개 모델 학습이라 trial당 ~10-15분.
#
# **예산**: 18시간 timeout. ~80-100 trials 예상.
#
# **산출**: `4_output/last_test_b/trials/trial_NNNN/` × N + `summary.csv`.
#
# **게이트 (사후 검사)**: 단독 val < 0.005994 AND max_corr_with_11base < 0.97.
#
# **실행 방법**: 이 노트북만 다른 PC로 옮겨서 실행하면 됨 (Colab/Local 자동 부트스트랩).

# %% [markdown]
# ## 1. 환경 + import (self-contained)

# %%
import os, sys, json, time, math

GDRIVE_FINAL_ID = '1HR7LlQmp4n9wGh2WneyVex2mCZ-poiY9'

try:
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    if not os.path.exists('/content/project/setup.py'):
        os.system('pip install -q gdown')
        os.system('gdown 1AD4PDBnDVjp-LSna6puB7qLnpBqB7j_I -O /content/code.zip')
        os.system('unzip -qo /content/code.zip -d /content/project')
        os.makedirs('/content/project/0_data', exist_ok=True)
        os.system('gdown 1yOUo0_wPLcuZBSJIK592b00YkSIlk4zO -O /content/project/0_data/dataset.zip')
        os.system('unzip -qo /content/project/0_data/dataset.zip -d /content/project/0_data')
        os.remove('/content/project/0_data/dataset.zip')
    if not os.path.exists('/content/project/2_preprocessing/cleaning.py'):
        os.system('gdown 1Rh0ByOS4Gama8XHuvY7KkOHo278H9YLr -O /content/preprocessing.zip')
        os.system('unzip -qo /content/preprocessing.zip -d /content/project')
    if not os.path.exists('/content/project/3_modeling/final/modules/preprocess.py'):
        assert GDRIVE_FINAL_ID, 'GDRIVE_FINAL_ID 비어있음'
        os.makedirs('/content/project/3_modeling/final', exist_ok=True)
        os.system(f'gdown {GDRIVE_FINAL_ID} -O /content/final.zip')
        os.system('unzip -qo /content/final.zip -d /content/project/3_modeling/final')
    sys.path.insert(0, '/content/project')
    # %run /content/project/setup.py
except ImportError:
    # %run ../../setup.py

import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from utils.config import PROJECT_ROOT, SEED, TARGET_COL, KEY_COL, DIE_KEY_COL, OUTPUT_DIR
from utils.data import load_all, get_feat_cols, split_xs

MODEL_ROOT = os.path.join(PROJECT_ROOT, '3_modeling')
if MODEL_ROOT not in sys.path:
    sys.path.insert(0, MODEL_ROOT)

from final.modules import preprocess

import lightgbm as lgb
import optuna
from sklearn.model_selection import KFold

import logging
logging.getLogger('lightgbm').setLevel(logging.ERROR)
optuna.logging.set_verbosity(optuna.logging.WARNING)

print(f'PROJECT_ROOT = {PROJECT_ROOT}')
print(f'SEED = {SEED}')
# Out:
# setup 완료
# PROJECT_ROOT = c:\Users\Dell5371\Desktop\기업연계프로젝트
# SEED = 42

# %% [markdown]
# ## 2. 설정

# %%
USER       = 'jh'
N_FOLDS    = 5
CLIP_Y_EXTREME = True

TIMEOUT_HOURS = 18.0
TIMEOUT_SEC   = int(TIMEOUT_HOURS * 3600)
N_TRIALS_CAP  = 200
N_STARTUP     = 20

OUT_DIR = os.path.join(OUTPUT_DIR, 'last_test_b')
os.makedirs(OUT_DIR, exist_ok=True)

EXP_ID = 'last-test-b-ts-reverse-hpo'
DB_PATH = os.path.join(OUT_DIR, f'optuna_{USER}_{EXP_ID}.db')

BEST_SINGLE_VAL = 0.005709
THR_SINGLE_VAL  = BEST_SINGLE_VAL * 1.05
THR_CORR_VS_11  = 0.97

print(f'EXP_ID={EXP_ID}')
print(f'TIMEOUT={TIMEOUT_HOURS:.1f}h ({TIMEOUT_SEC}s) | N_TRIALS_CAP={N_TRIALS_CAP} | N_STARTUP={N_STARTUP}')
print(f'OUT_DIR={OUT_DIR}')
print(f'게이트: single_val<{THR_SINGLE_VAL:.6f}, max_corr_vs_11<{THR_CORR_VS_11}')
print(f'저장 정책: 매 trial 메타는 SQLite의 user_attrs에 누적, best_*.csv 1세트만 덮어쓰기')
# Out:
# EXP_ID=last-test-b-ts-reverse-hpo
# TIMEOUT=18.0h (64800s) | N_TRIALS_CAP=200 | N_STARTUP=20
# OUT_DIR=c:\Users\Dell5371\Desktop\기업연계프로젝트\4_output\last_test_b
# 게이트: single_val<0.005994, max_corr_vs_11<0.97
# 저장 정책: 매 trial 메타는 SQLite의 user_attrs에 누적, best_*.csv 1세트만 덮어쓰기

# %% [markdown]
# ## 3. 데이터 로드 + 전처리 (1회)

# %%
xs, ys = load_all()
feat_cols = get_feat_cols(xs)
xs_dict = split_xs(xs)

ys_input = {k: v.copy() for k, v in ys.items()}
if CLIP_Y_EXTREME:
    y_raw = ys_input['train'][TARGET_COL]
    second_max = y_raw[y_raw < y_raw.max()].max()
    n_clipped = int((y_raw >= 1.0).sum())
    ys_input['train'][TARGET_COL] = y_raw.clip(upper=second_max)
    print(f'[CLIP_Y_EXTREME] 1.0 → {second_max:.6f} clip ({n_clipped}개)')

y_train_unit = ys_input['train'].set_index(KEY_COL)[TARGET_COL]
y_val_unit   = ys_input['validation'].set_index(KEY_COL)[TARGET_COL]
y_test_unit  = ys_input['test'].set_index(KEY_COL)[TARGET_COL]

# 03b log1p preset 전처리 1회
PARAMS = {
    'missing_threshold':          0.5,
    'corr_threshold':             0.90,
    'corr_keep_by':               'std',
    'add_indicator':              True,
    'indicator_threshold':        0.25,
    'spatial_max_dist':           5.0,
    'post_impute_corr_threshold': 0.99,
    'post_impute_corr_keep_by':   'std',
}
pp = preprocess.run(xs, ys_input, feat_cols, xs_dict, params=PARAMS)
xs_train_die = pp['xs_train']
xs_val_die   = pp['xs_val']
xs_test_die  = pp['xs_test']
feat_cols_clean = pp['feat_cols']

X_train_die = xs_train_die[feat_cols_clean].values.astype(np.float64)
X_val_die   = xs_val_die[feat_cols_clean].values.astype(np.float64)
X_test_die  = xs_test_die[feat_cols_clean].values.astype(np.float64)
uid_train_die = xs_train_die[KEY_COL].values
uid_val_die   = xs_val_die[KEY_COL].values
uid_test_die  = xs_test_die[KEY_COL].values

y_train_die_broadcast = pd.Series(uid_train_die).map(y_train_unit).values.astype(np.float64)
assert not pd.isna(y_train_die_broadcast).any(), 'unmapped train die y'
y_bin_die_broadcast = (y_train_die_broadcast > 0).astype(np.int32)

unit_ids_train_unique = y_train_unit.index.values
kf_global = KFold(n_splits=N_FOLDS, shuffle=True, random_state=SEED)
FOLDS = list(kf_global.split(unit_ids_train_unique))

n_train_die = len(X_train_die)
n_val_die   = len(X_val_die)
n_test_die  = len(X_test_die)

print(f'\n[cleaning] feat_cols_clean={len(feat_cols_clean)}')
print(f'  X_train_die: {X_train_die.shape}, val: {X_val_die.shape}, test: {X_test_die.shape}')
print(f'  unit train={len(y_train_unit):,}, val={len(y_val_unit):,}, test={len(y_test_unit):,}')
print(f'  fold: {N_FOLDS}-fold unit-level shuffle SEED={SEED}')
# Out:
# Xs: (174572, 1091)  |  Ys: train=26,187, val=8,727, test=8,729
# [CLIP_Y_EXTREME] 1.0 → 0.097417 clip (1개)
# [Stage 0] 웨이퍼맵 사전 제외: 1087 → 1033 (54개 제거)
# ============================================================
# 클리닝 파이프라인 시작
# 원본 feature 수: 1033
# ============================================================
# [상수/극저분산 제거] threshold=1e-06
#   제거: 105개, 잔여: 928개
#     컬럼: 1033 → 928 (105개 제거)
#     DataFrame: (104748, 986)
#
# [고결측 제거] threshold=50%
#   제거: 5개, 잔여: 923개
#     컬럼: 928 → 923 (5개 제거)
#     DataFrame: (104748, 981)
#
# [중복 컬럼 제거] sample_n=5000
#   제거: 27개, 잔여: 896개
#     컬럼: 923 → 896 (27개 제거)
#     DataFrame: (104748, 954)
#
# [고상관 제거] threshold=0.9, keep_by=std (std)
#   제거: 332개, 잔여: 564개
#     컬럼: 896 → 564 (332개 제거)
#     DataFrame: (104748, 622)
#
# [결측 indicator] 4개 컬럼 추가 (결측률 >= 25%)
# [공간 보간 imputation] 총 결측: 343,494
#   train-only 모드: train 104,748 / 전체 174,572 행
#   1단계 (공간 보간, dist<=5.0): 156,772개 채움 → 잔여: 186,722
#   2단계 (lot 평균, train 기준): 105,526개 채움 → 잔여: 81,196
#   3단계 (train 전체 평균): 81,196개 채움 → 잔여: 0
#
#   [요약] 343,494 → 공간(156,772) → lot(105,526) → 전체(81,196) → 잔여(0)
#
# [고상관 제거] threshold=0.99, keep_by=std (std)
#   제거: 0개, 잔여: 564개
#     [고상관 제거 2차 / imputation 후] threshold=0.99
#     컬럼: 564 → 564 (0개 제거)
#     DataFrame: (104748, 626)
#
# ============================================================
# 클리닝 완료: 1033 → 564 features (469개 제거)
#   + indicator 컬럼: 4개 → 총 568개
#   train: (104748, 626)
#   val:   (34908, 626)
#   test:  (34916, 626)
# ============================================================
# ============================================================
# 이상치 처리 파이프라인 시작 (method=winsorize)
# ============================================================
# [이상치 탐지] IQR × 1.5
#   이상치 > 5%: 107개
#   이상치 > 10%: 59개
# [Winsorization] lower=0%, upper=99%
#   적용 feature: 568개
#
# ============================================================
# 이상치 처리 완료 (method=winsorize)
#   train: (104748, 626)
# ============================================================
#
# [cleaning] feat_cols_clean=568
#   X_train_die: (104748, 568), val: (34908, 568), test: (34916, 568)
#   unit train=26,187, val=8,727, test=8,729
#   fold: 5-fold unit-level shuffle SEED=42

# %% [markdown]
# ## 4. Feature gain importance 캐싱 (top_300/200/100)

# %%
import pickle

with open(os.path.join(OUTPUT_DIR, 'final', 'reg_only', 'lgbm', 'fold_models.pkl'), 'rb') as f:
    fm_data = pickle.load(f)

# fold_models.pkl 구조 호환:
#   (a) dict {'fold_models': [...], 'feature_names': [...], ...} — 표준
#   (b) dict인데 'feature_names'가 None — 과거 저장본
#   (c) list [LGBMRegressor, ...] — legacy
if isinstance(fm_data, dict):
    fold_models_list = fm_data.get('fold_models', None)
    lgbm_feat_names  = fm_data.get('feature_names', None)
else:
    fold_models_list = list(fm_data)
    lgbm_feat_names  = None

assert fold_models_list is not None and len(fold_models_list) > 0, 'fold_models.pkl 비어있음'

# feature_names가 None이면 booster에서 직접 복구
def _recover_feat_names(models):
    m0 = models[0]
    if hasattr(m0, 'booster_'):
        names = m0.booster_.feature_name()
    elif hasattr(m0, 'feature_name_'):
        names = list(m0.feature_name_)
    else:
        raise RuntimeError('cached LGBM model에서 feature_name 복구 실패')
    return list(names)

if lgbm_feat_names is None or not hasattr(lgbm_feat_names, '__iter__'):
    print('[fold_models.pkl] feature_names=None → booster에서 복구')
    lgbm_feat_names = _recover_feat_names(fold_models_list)
else:
    lgbm_feat_names = list(lgbm_feat_names)

print(f'fold_models: {len(fold_models_list)}개 | feature_names: {len(lgbm_feat_names)}개')

gains = []
for m in fold_models_list:
    if hasattr(m, 'booster_'):
        gains.append(m.booster_.feature_importance(importance_type='gain'))
    elif hasattr(m, 'feature_importances_'):
        gains.append(m.feature_importances_)
mean_gain = np.mean(gains, axis=0)
assert len(mean_gain) == len(lgbm_feat_names), \
    f'gain 길이({len(mean_gain)}) != feat_names 길이({len(lgbm_feat_names)})'

common_feats = [f for f in lgbm_feat_names if f in feat_cols_clean]
print(f'  교집합 (lgbm_feat_names ∩ feat_cols_clean): {len(common_feats)}개')
assert len(common_feats) >= 100, f'common_feats가 너무 적음({len(common_feats)}) — 전처리 PARAMS 미스매치 의심'

gain_dict = {f: g for f, g in zip(lgbm_feat_names, mean_gain)}
common_gains = np.array([gain_dict[f] for f in common_feats])

# top_300, top_200, top_100
def _top_k_idx(k):
    k_eff = min(k, len(common_feats))
    sorted_feats = [f for f, g in sorted(zip(common_feats, common_gains), key=lambda x: -x[1])[:k_eff]]
    return [feat_cols_clean.index(f) for f in sorted_feats]

TOP_300_IDX = _top_k_idx(300)
TOP_200_IDX = _top_k_idx(200)
TOP_100_IDX = _top_k_idx(100)

FEAT_SUBSET_MAP = {
    'full':    None,
    'top_300': TOP_300_IDX,
    'top_200': TOP_200_IDX,
    'top_100': TOP_100_IDX,
}
print(f'feat subset 캐싱: full({len(feat_cols_clean)}), '
      f'top_300({len(TOP_300_IDX)}), top_200({len(TOP_200_IDX)}), top_100({len(TOP_100_IDX)})')
# Out:
# fold_models: 5개 | feature_names: 568개
#   교집합 (lgbm_feat_names ∩ feat_cols_clean): 568개
# feat subset 캐싱: full(568), top_300(300), top_200(200), top_100(100)

# %% [markdown]
# ## 5. 11-base OOF 잔차 로드 (게이트 corr 계산용)

# %%
BASE_OOF_PATHS = {
    'zit_only':                 os.path.join(OUTPUT_DIR, 'final', 'zit_only',      'oof_unit.csv'),
    'bag_zit_combined_best':    os.path.join(OUTPUT_DIR, '_temp', 'bag_zit_combined_best',    'oof_unit.csv'),
    'bag_zit_hpo':              os.path.join(OUTPUT_DIR, '_temp', 'bag_zit_hpo',              'oof_unit.csv'),
    'bag_zit_combined_best_xy': os.path.join(OUTPUT_DIR, '_temp', 'bag_zit_combined_best_xy', 'oof_unit.csv'),
    'bag_zit_pp_hpo':           os.path.join(OUTPUT_DIR, '_temp', 'bag_zit_pp_hpo',           'oof_unit.csv'),
    'bag_zit_fixed_ge':         os.path.join(OUTPUT_DIR, '_temp', 'bag_zit_fixed_ge',         'oof_unit.csv'),
    'reg__catboost':            os.path.join(OUTPUT_DIR, 'final', 'reg_only', 'catboost', 'oof_unit.csv'),
    'reg__lgbm':                os.path.join(OUTPUT_DIR, 'final', 'reg_only', 'lgbm',     'oof_unit.csv'),
    'reg__et':                  os.path.join(OUTPUT_DIR, 'final', 'reg_only', 'et',       'oof_unit.csv'),
    'reg__enet':                os.path.join(OUTPUT_DIR, 'final', 'reg_only', 'enet',     'oof_unit.csv'),
}

def _load_base_pred(path, y_series):
    df = pd.read_csv(path)
    return df.set_index(KEY_COL)['pred'].reindex(y_series.index).values

base_oof_pred = {k: _load_base_pred(p, y_train_unit) for k, p in BASE_OOF_PATHS.items()}
base_oof_resid = {k: y_train_unit.values - v for k, v in base_oof_pred.items()}
print(f'[11-base OOF 잔차 로드] {len(base_oof_resid)}개')
# Out:
# [11-base OOF 잔차 로드] 10개

# %% [markdown]
# ## 6. 헬퍼 함수

# %%
def _mean_die_to_unit(pred_die, uid_die):
    unit_id = np.asarray(uid_die)
    unique_units, inverse = np.unique(unit_id, return_inverse=True)
    pred_sum = np.zeros(len(unique_units))
    cnt      = np.zeros(len(unique_units))
    np.add.at(pred_sum, inverse, pred_die)
    np.add.at(cnt,      inverse, 1.0)
    return pred_sum / cnt, unique_units


def _rmse_unit(pred_unit_arr, unique_units, y_unit_series):
    s = pd.Series(pred_unit_arr, index=unique_units).reindex(y_unit_series.index)
    return float(np.sqrt(np.mean((s.values - y_unit_series.values) ** 2)))


def _save_unit_csv(uids, pred, y_true, path):
    pd.DataFrame({KEY_COL: uids, 'pred': pred, TARGET_COL: y_true}).to_csv(path, index=False)


def _max_corr_with_11base(oof_unit_pred_aligned):
    new_resid = y_train_unit.values - oof_unit_pred_aligned
    # 모델이 상수로 붕괴(분산 0) → corr 정의 불가 → 게이트 fail (1.0)로 처리
    if np.std(new_resid) < 1e-12:
        return 1.0
    cs = []
    for r in base_oof_resid.values():
        c = float(np.corrcoef(new_resid, r)[0, 1])
        if not np.isfinite(c):
            c = 1.0
        cs.append(c)
    return max(cs)


def _slice_features(feat_subset_name):
    idx = FEAT_SUBSET_MAP[feat_subset_name]
    if idx is None:
        return X_train_die, X_val_die, X_test_die, len(feat_cols_clean)
    return X_train_die[:, idx], X_val_die[:, idx], X_test_die[:, idx], len(idx)


# ── 글로벌 best 트래커 (val_rmse 기준) ──
BEST_VAL_RMSE = float('inf')

def _maybe_save_best(oof_s, val_s, test_s, val_rmse, meta_dict):
    """새 best (val_rmse 기준)이면 best_*.csv + best_meta.json 덮어쓰기."""
    global BEST_VAL_RMSE
    if val_rmse < BEST_VAL_RMSE:
        BEST_VAL_RMSE = val_rmse
        _save_unit_csv(y_train_unit.index.values, oof_s.values,  y_train_unit.values, os.path.join(OUT_DIR, 'best_oof_unit.csv'))
        _save_unit_csv(y_val_unit.index.values,   val_s.values,  y_val_unit.values,   os.path.join(OUT_DIR, 'best_val_unit.csv'))
        _save_unit_csv(y_test_unit.index.values,  test_s.values, y_test_unit.values,  os.path.join(OUT_DIR, 'best_test_unit.csv'))
        with open(os.path.join(OUT_DIR, 'best_meta.json'), 'w', encoding='utf-8') as f:
            json.dump(meta_dict, f, indent=2, ensure_ascii=False, default=str)
        return True
    return False


def _train_path_b_one_fold(X_tr, y_tr_continuous, y_tr_bin, X_others, hp, w0, reg_obj, clf_spw):
    sw = np.where(y_tr_continuous == 0, w0, 1.0)
    y_tr_log = np.log1p(y_tr_continuous)
    reg_params = dict(hp)
    if reg_obj.startswith('tweedie'):
        reg_params['objective'] = 'tweedie'
        reg_params['tweedie_variance_power'] = float(reg_obj.split('_')[1])
    else:
        reg_params['objective'] = reg_obj
    reg = lgb.LGBMRegressor(**reg_params)
    reg.fit(X_tr, y_tr_log, sample_weight=sw)

    reg_train_log = reg.predict(X_tr)
    reg_train_y   = np.clip(np.expm1(reg_train_log), 0.0, None)
    X_tr_aug = np.hstack([X_tr, reg_train_y.reshape(-1, 1)])

    clf_params = dict(hp)
    clf_params['objective'] = 'binary'
    clf_params['scale_pos_weight'] = clf_spw
    clf = lgb.LGBMClassifier(**clf_params)
    clf.fit(X_tr_aug, y_tr_bin)

    results = []
    for X_o in X_others:
        reg_log_o = reg.predict(X_o)
        reg_y_o   = np.clip(np.expm1(reg_log_o), 0.0, None)
        X_o_aug   = np.hstack([X_o, reg_y_o.reshape(-1, 1)])
        prob_o = clf.predict_proba(X_o_aug)[:, 1]
        prob_o = np.clip(prob_o, 0.0, 1.0)
        results.append(prob_o * reg_y_o)
    return results


def train_ts_reverse_trial(hp_lgbm, w0, reg_obj, clf_spw, feat_subset_name):
    """학습 + 예측 반환 (저장 안 함)."""
    Xtr_full, Xvl_full, Xte_full, n_feat_used = _slice_features(feat_subset_name)

    oof_die_pred  = np.full(n_train_die, np.nan)
    val_die_pred  = np.zeros(n_val_die)
    test_die_pred = np.zeros(n_test_die)

    t0 = time.time()
    for fold_idx, (tr_uidx, vl_uidx) in enumerate(FOLDS):
        tr_units = unit_ids_train_unique[tr_uidx]
        vl_units = unit_ids_train_unique[vl_uidx]
        tr_die_mask = np.isin(uid_train_die, tr_units)
        vl_die_mask = np.isin(uid_train_die, vl_units)
        X_tr  = Xtr_full[tr_die_mask]
        X_vl  = Xtr_full[vl_die_mask]
        y_tr  = y_train_die_broadcast[tr_die_mask]
        yb_tr = y_bin_die_broadcast[tr_die_mask]

        f_vl, f_v, f_t = _train_path_b_one_fold(
            X_tr, y_tr, yb_tr,
            [X_vl, Xvl_full, Xte_full],
            hp_lgbm, w0, reg_obj, clf_spw,
        )
        oof_die_pred[vl_die_mask] = f_vl
        val_die_pred  += f_v / N_FOLDS
        test_die_pred += f_t / N_FOLDS

    assert not np.isnan(oof_die_pred).any()

    oof_u, oof_uids   = _mean_die_to_unit(oof_die_pred,  uid_train_die)
    val_u, val_uids   = _mean_die_to_unit(val_die_pred,  uid_val_die)
    test_u, test_uids = _mean_die_to_unit(test_die_pred, uid_test_die)

    oof_rmse  = _rmse_unit(oof_u,  oof_uids,  y_train_unit)
    val_rmse  = _rmse_unit(val_u,  val_uids,  y_val_unit)
    test_rmse = _rmse_unit(test_u, test_uids, y_test_unit)

    oof_s  = pd.Series(oof_u,  index=oof_uids).reindex(y_train_unit.index)
    val_s  = pd.Series(val_u,  index=val_uids).reindex(y_val_unit.index)
    test_s = pd.Series(test_u, index=test_uids).reindex(y_test_unit.index)

    max_corr11 = _max_corr_with_11base(oof_s.values)

    return {
        'oof_rmse': oof_rmse, 'val_rmse': val_rmse, 'test_rmse': test_rmse,
        'max_corr_vs_11base': max_corr11,
        'oof_s': oof_s, 'val_s': val_s, 'test_s': test_s,
        'n_feat_used': n_feat_used,
        'elapsed': time.time() - t0,
    }


print('train_ts_reverse_trial 정의 완료')
# Out:
# train_ts_reverse_trial 정의 완료

# %% [markdown]
# ## 7. Optuna HPO 실행 (TIMEOUT_SEC 자동 종료)

# %%
def objective_b(trial):
    hp = dict(
        n_estimators=trial.suggest_int('n_estimators', 100, 3000),
        learning_rate=trial.suggest_float('learning_rate', 0.005, 0.3, log=True),
        num_leaves=trial.suggest_int('num_leaves', 8, 512),
        max_depth=trial.suggest_int('max_depth', 3, 14),
        min_child_samples=trial.suggest_int('min_child_samples', 5, 400),
        subsample=trial.suggest_float('subsample', 0.5, 1.0),
        subsample_freq=1,
        colsample_bytree=trial.suggest_float('colsample_bytree', 0.1, 1.0),
        reg_alpha=trial.suggest_float('reg_alpha', 1e-8, 30.0, log=True),
        reg_lambda=trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        min_split_gain=trial.suggest_float('min_split_gain', 1e-9, 1.0, log=True),
        path_smooth=trial.suggest_float('path_smooth', 0.0, 50.0),
        random_state=SEED, n_jobs=7, verbose=-1,  # 14코어 PC에서 둘 동시 실행 → 절반 분배
    )
    w0 = trial.suggest_float('w0', 0.05, 1.0, log=True)
    reg_obj = trial.suggest_categorical(
        'reg_objective',
        ['regression', 'poisson', 'tweedie_1.2', 'tweedie_1.3',
         'tweedie_1.5', 'tweedie_1.7', 'tweedie_1.8'],
    )
    clf_spw = trial.suggest_categorical('clf_scale_pos_weight', [1.0, 1.5, 2.43, 3.5])
    feat_subset = trial.suggest_categorical('feat_subset', ['full', 'top_300', 'top_200', 'top_100'])

    r = train_ts_reverse_trial(hp, w0, reg_obj, clf_spw, feat_subset)

    trial.set_user_attr('val_rmse',           r['val_rmse'])
    trial.set_user_attr('test_rmse',          r['test_rmse'])
    trial.set_user_attr('max_corr_vs_11base', r['max_corr_vs_11base'])
    trial.set_user_attr('n_feat_used',        r['n_feat_used'])
    trial.set_user_attr('elapsed_s',          r['elapsed'])

    meta_dict = {
        'trial_number': trial.number,
        'oof_rmse': r['oof_rmse'], 'val_rmse': r['val_rmse'], 'test_rmse': r['test_rmse'],
        'max_corr_vs_11base': r['max_corr_vs_11base'],
        'hp_lgbm': {k: (float(v) if hasattr(v, 'item') else v) for k, v in hp.items()},
        'w0': float(w0), 'reg_objective': reg_obj, 'clf_scale_pos_weight': float(clf_spw),
        'feat_subset': feat_subset, 'n_features_used': r['n_feat_used'],
        'CLIP_Y_EXTREME': CLIP_Y_EXTREME, 'feat_cols_clean_n': len(feat_cols_clean),
        'SEED': int(SEED), 'elapsed_seconds': r['elapsed'],
    }
    is_new_best = _maybe_save_best(r['oof_s'], r['val_s'], r['test_s'], r['val_rmse'], meta_dict)
    best_mark = ' ★new_best' if is_new_best else ''

    p1 = '✅' if r['val_rmse'] < THR_SINGLE_VAL else '❌'
    p2 = '✅' if r['max_corr_vs_11base'] < THR_CORR_VS_11 else '❌'
    print(f'trial {trial.number:04d} | reg_obj={reg_obj} feat={feat_subset} w0={w0:.3f} spw={clf_spw} '
          f'| val={r["val_rmse"]:.6f}{p1} corr={r["max_corr_vs_11base"]:.4f}{p2} '
          f'| {r["elapsed"]:.0f}s{best_mark}')

    return r['oof_rmse']


study = optuna.create_study(
    direction='minimize',
    study_name=EXP_ID,
    storage=f'sqlite:///{DB_PATH}',
    load_if_exists=True,
    sampler=optuna.samplers.TPESampler(seed=SEED, n_startup_trials=N_STARTUP),
)
study.set_user_attr('exp_memo', 'last_test_b — two_stage_reverse full HPO + diversity (reg_objective × feat_subset)')
study.set_user_attr('timeout_hours', TIMEOUT_HOURS)

for t in study.trials:
    if t.state == optuna.trial.TrialState.COMPLETE:
        v = t.user_attrs.get('val_rmse', float('inf'))
        if v < BEST_VAL_RMSE:
            BEST_VAL_RMSE = v
print(f'\n현재 best_val_rmse (복구): {BEST_VAL_RMSE if BEST_VAL_RMSE != float("inf") else "없음"}')

print(f'\n=== Optuna HPO 시작 (timeout={TIMEOUT_HOURS}h, startup={N_STARTUP}, sampler=TPE) ===')
print(f'  탐색 axes: 11 LGBM HP + w0 + reg_objective(7) + clf_spw(4) + feat_subset(4) = 15축')
t_total = time.time()
try:
    study.optimize(objective_b, n_trials=N_TRIALS_CAP, timeout=TIMEOUT_SEC)
except KeyboardInterrupt:
    print('\n[KeyboardInterrupt] HPO 중단 — 지금까지 trial은 SQLite에 저장됨')

print(f'\n[HPO 종료] {time.time()-t_total:.0f}s, completed trials: {len(study.trials)}')
print(f'best OOF RMSE = {study.best_value:.6f}')
print(f'best params:')
for k, v in study.best_trial.params.items():
    print(f'  {k:25s} = {v}')
# Out:
# 현재 best_val_rmse (복구): 0.005799724007247335
#
# === Optuna HPO 시작 (timeout=18.0h, startup=20, sampler=TPE) ===
#   탐색 axes: 11 LGBM HP + w0 + reg_objective(7) + clf_spw(4) + feat_subset(4) = 15축
# trial 0004 | reg_obj=regression feat=top_200 w0=0.914 spw=1.5 | val=0.006061❌ corr=0.9957❌ | 260s
# trial 0005 | reg_obj=tweedie_1.5 feat=full w0=0.388 spw=2.43 | val=0.005800✅ corr=0.9921❌ | 520s
# trial 0006 | reg_obj=tweedie_1.3 feat=top_100 w0=0.254 spw=1.0 | val=0.005963✅ corr=0.9740❌ | 313s
# trial 0007 | reg_obj=poisson feat=full w0=0.488 spw=1.5 | val=0.005830✅ corr=0.9976❌ | 509s
# trial 0008 | reg_obj=poisson feat=top_100 w0=0.252 spw=1.0 | val=0.005821✅ corr=0.9980❌ | 202s
# trial 0009 | reg_obj=tweedie_1.3 feat=top_300 w0=0.310 spw=1.0 | val=0.005874✅ corr=0.9907❌ | 291s
# trial 0010 | reg_obj=tweedie_1.5 feat=top_300 w0=0.099 spw=1.5 | val=0.005879✅ corr=0.9884❌ | 354s
# trial 0011 | reg_obj=tweedie_1.2 feat=top_200 w0=0.342 spw=3.5 | val=0.005732✅ corr=0.9955❌ | 336s ★new_best
# trial 0012 | reg_obj=regression feat=top_200 w0=0.162 spw=1.0 | val=0.005888✅ corr=0.9652✅ | 318s
# trial 0013 | reg_obj=tweedie_1.8 feat=top_300 w0=0.083 spw=2.43 | val=0.005753✅ corr=0.9937❌ | 530s
# trial 0014 | reg_obj=tweedie_1.2 feat=top_100 w0=0.138 spw=3.5 | val=0.005929✅ corr=0.9666✅ | 525s
# trial 0015 | reg_obj=tweedie_1.5 feat=top_300 w0=0.541 spw=1.0 | val=0.005898✅ corr=0.9960❌ | 302s
# trial 0016 | reg_obj=regression feat=top_200 w0=0.056 spw=3.5 | val=0.005933✅ corr=0.9674✅ | 604s
# trial 0017 | reg_obj=tweedie_1.3 feat=top_200 w0=0.197 spw=3.5 | val=0.005753✅ corr=0.9955❌ | 297s
# trial 0018 | reg_obj=regression feat=full w0=0.561 spw=2.43 | val=0.005835✅ corr=0.9888❌ | 1233s
# trial 0019 | reg_obj=tweedie_1.3 feat=top_100 w0=0.120 spw=3.5 | val=0.005797✅ corr=0.9963❌ | 316s
# trial 0020 | reg_obj=tweedie_1.2 feat=full w0=0.152 spw=2.43 | val=0.005719✅ corr=0.9989❌ | 551s ★new_best
# trial 0021 | reg_obj=tweedie_1.2 feat=full w0=0.072 spw=2.43 | val=0.005760✅ corr=0.9989❌ | 222s
# trial 0022 | reg_obj=tweedie_1.2 feat=top_200 w0=0.172 spw=3.5 | val=0.005731✅ corr=0.9976❌ | 440s
# trial 0023 | reg_obj=tweedie_1.2 feat=top_200 w0=0.183 spw=3.5 | val=0.005730✅ corr=0.9980❌ | 366s
# trial 0024 | reg_obj=tweedie_1.2 feat=top_200 w0=0.167 spw=3.5 | val=0.005732✅ corr=0.9974❌ | 342s
# trial 0025 | reg_obj=tweedie_1.7 feat=top_200 w0=0.132 spw=3.5 | val=0.005759✅ corr=0.9886❌ | 370s
# trial 0026 | reg_obj=tweedie_1.2 feat=full w0=0.104 spw=3.5 | val=0.005749✅ corr=0.9949❌ | 422s
# trial 0027 | reg_obj=tweedie_1.2 feat=top_200 w0=0.200 spw=2.43 | val=0.005762✅ corr=0.9901❌ | 521s
# trial 0028 | reg_obj=tweedie_1.2 feat=top_200 w0=0.164 spw=3.5 | val=0.005763✅ corr=0.9873❌ | 586s
# trial 0029 | reg_obj=tweedie_1.7 feat=full w0=0.075 spw=3.5 | val=0.005751✅ corr=0.9916❌ | 536s
# trial 0030 | reg_obj=tweedie_1.8 feat=top_200 w0=0.106 spw=2.43 | val=0.005844✅ corr=0.9885❌ | 306s
# trial 0031 | reg_obj=tweedie_1.2 feat=top_200 w0=0.216 spw=1.5 | val=0.005753✅ corr=0.9977❌ | 393s
# trial 0032 | reg_obj=tweedie_1.2 feat=top_200 w0=0.166 spw=3.5 | val=0.005733✅ corr=0.9975❌ | 433s
# trial 0033 | reg_obj=tweedie_1.2 feat=top_200 w0=0.153 spw=3.5 | val=0.005742✅ corr=0.9976❌ | 427s
# trial 0034 | reg_obj=tweedie_1.2 feat=top_200 w0=0.197 spw=3.5 | val=0.005759✅ corr=0.9887❌ | 492s
# trial 0035 | reg_obj=tweedie_1.2 feat=top_200 w0=0.285 spw=3.5 | val=0.005733✅ corr=0.9963❌ | 568s
# trial 0036 | reg_obj=tweedie_1.2 feat=full w0=0.122 spw=2.43 | val=0.005749✅ corr=0.9920❌ | 623s
# trial 0037 | reg_obj=tweedie_1.2 feat=top_200 w0=0.183 spw=3.5 | val=0.005756✅ corr=0.9932❌ | 432s
# trial 0038 | reg_obj=poisson feat=full w0=0.243 spw=2.43 | val=0.005716✅ corr=0.9990❌ | 583s ★new_best
# trial 0039 | reg_obj=poisson feat=full w0=0.246 spw=2.43 | val=0.005728✅ corr=0.9978❌ | 592s
# trial 0040 | reg_obj=poisson feat=full w0=0.396 spw=2.43 | val=0.005767✅ corr=0.9969❌ | 566s
# trial 0041 | reg_obj=poisson feat=full w0=0.247 spw=2.43 | val=0.005750✅ corr=0.9930❌ | 812s
# trial 0042 | reg_obj=poisson feat=full w0=0.226 spw=2.43 | val=0.005720✅ corr=0.9990❌ | 438s
# trial 0043 | reg_obj=poisson feat=full w0=0.232 spw=2.43 | val=0.005724✅ corr=0.9987❌ | 420s
# trial 0044 | reg_obj=poisson feat=full w0=0.318 spw=2.43 | val=0.005752✅ corr=0.9936❌ | 571s
# trial 0045 | reg_obj=poisson feat=full w0=0.235 spw=2.43 | val=0.005722✅ corr=0.9979❌ | 436s
# trial 0046 | reg_obj=poisson feat=full w0=0.442 spw=2.43 | val=0.005764✅ corr=0.9983❌ | 443s
# trial 0047 | reg_obj=poisson feat=full w0=0.737 spw=2.43 | val=0.005838✅ corr=0.9980❌ | 411s
# trial 0048 | reg_obj=poisson feat=full w0=0.287 spw=2.43 | val=0.005755✅ corr=0.9930❌ | 521s
# trial 0049 | reg_obj=poisson feat=full w0=0.225 spw=2.43 | val=0.005717✅ corr=0.9987❌ | 595s
# trial 0050 | reg_obj=poisson feat=full w0=0.341 spw=2.43 | val=0.005748✅ corr=0.9948❌ | 635s
# trial 0051 | reg_obj=poisson feat=full w0=0.217 spw=1.5 | val=0.005754✅ corr=0.9955❌ | 691s
# trial 0052 | reg_obj=poisson feat=full w0=0.269 spw=2.43 | val=0.005757✅ corr=0.9968❌ | 511s
# trial 0053 | reg_obj=poisson feat=full w0=0.224 spw=2.43 | val=0.005716✅ corr=0.9992❌ | 571s ★new_best
# trial 0054 | reg_obj=tweedie_1.5 feat=full w0=0.148 spw=2.43 | val=0.005742✅ corr=0.9940❌ | 510s
# trial 0055 | reg_obj=poisson feat=top_300 w0=0.211 spw=2.43 | val=0.005715✅ corr=0.9989❌ | 483s ★new_best
# trial 0056 | reg_obj=poisson feat=top_300 w0=0.362 spw=1.0 | val=0.005856✅ corr=0.9979❌ | 492s
# trial 0057 | reg_obj=poisson feat=top_300 w0=0.218 spw=2.43 | val=0.005732✅ corr=0.9952❌ | 509s
# trial 0058 | reg_obj=poisson feat=top_300 w0=0.300 spw=2.43 | val=0.005725✅ corr=0.9988❌ | 415s
# trial 0059 | reg_obj=tweedie_1.8 feat=top_300 w0=0.299 spw=2.43 | val=0.005747✅ corr=0.9942❌ | 516s
# trial 0060 | reg_obj=poisson feat=top_300 w0=0.266 spw=2.43 | val=0.005719✅ corr=0.9990❌ | 461s
# trial 0061 | reg_obj=regression feat=top_300 w0=0.408 spw=1.5 | val=0.005813✅ corr=0.9979❌ | 445s
# trial 0062 | reg_obj=poisson feat=top_300 w0=0.267 spw=2.43 | val=0.005720✅ corr=0.9988❌ | 494s
# trial 0063 | reg_obj=poisson feat=top_300 w0=0.265 spw=2.43 | val=0.005721✅ corr=0.9989❌ | 452s
# trial 0064 | reg_obj=poisson feat=top_300 w0=0.197 spw=2.43 | val=0.005791✅ corr=0.9875❌ | 466s
# trial 0065 | reg_obj=tweedie_1.3 feat=top_100 w0=0.260 spw=2.43 | val=0.005724✅ corr=0.9979❌ | 352s
# trial 0066 | reg_obj=tweedie_1.7 feat=top_300 w0=0.333 spw=2.43 | val=0.005775✅ corr=0.9934❌ | 644s
# trial 0067 | reg_obj=poisson feat=top_300 w0=0.181 spw=1.0 | val=0.005830✅ corr=0.9976❌ | 273s
# trial 0068 | reg_obj=poisson feat=top_300 w0=0.208 spw=2.43 | val=0.005715✅ corr=0.9992❌ | 429s
# trial 0069 | reg_obj=tweedie_1.5 feat=top_100 w0=0.201 spw=2.43 | val=0.005734✅ corr=0.9937❌ | 373s
# trial 0070 | reg_obj=poisson feat=top_300 w0=0.224 spw=2.43 | val=0.005739✅ corr=0.9940❌ | 558s
# trial 0071 | reg_obj=tweedie_1.8 feat=top_300 w0=0.147 spw=2.43 | val=0.005742✅ corr=0.9910❌ | 501s
# trial 0072 | reg_obj=poisson feat=top_300 w0=0.251 spw=2.43 | val=0.005717✅ corr=0.9990❌ | 543s
# trial 0073 | reg_obj=poisson feat=top_300 w0=0.209 spw=2.43 | val=0.005714✅ corr=0.9988❌ | 547s ★new_best
# trial 0074 | reg_obj=poisson feat=top_300 w0=0.181 spw=2.43 | val=0.005714✅ corr=0.9987❌ | 542s ★new_best
# trial 0075 | reg_obj=poisson feat=top_300 w0=0.190 spw=2.43 | val=0.005792✅ corr=0.9913❌ | 441s
# trial 0076 | reg_obj=poisson feat=top_300 w0=0.130 spw=2.43 | val=0.005725✅ corr=0.9987❌ | 507s
# trial 0077 | reg_obj=regression feat=top_300 w0=0.210 spw=1.0 | val=0.005800✅ corr=0.9975❌ | 537s
# trial 0078 | reg_obj=tweedie_1.3 feat=top_300 w0=0.176 spw=1.5 | val=0.005749✅ corr=0.9954❌ | 642s
# trial 0079 | reg_obj=tweedie_1.7 feat=top_300 w0=0.243 spw=2.43 | val=0.005727✅ corr=0.9977❌ | 497s
# trial 0080 | reg_obj=poisson feat=top_300 w0=0.160 spw=2.43 | val=0.005784✅ corr=0.9935❌ | 550s
# trial 0081 | reg_obj=poisson feat=top_300 w0=0.281 spw=2.43 | val=0.005733✅ corr=0.9963❌ | 649s
# trial 0082 | reg_obj=poisson feat=top_300 w0=0.207 spw=2.43 | val=0.005717✅ corr=0.9987❌ | 536s
# trial 0083 | reg_obj=poisson feat=top_300 w0=0.204 spw=2.43 | val=0.005712✅ corr=0.9990❌ | 529s ★new_best
# trial 0084 | reg_obj=poisson feat=top_300 w0=0.188 spw=2.43 | val=0.005713✅ corr=0.9989❌ | 545s
# trial 0085 | reg_obj=poisson feat=top_300 w0=0.175 spw=2.43 | val=0.005713✅ corr=0.9990❌ | 518s
# trial 0086 | reg_obj=poisson feat=top_300 w0=0.139 spw=2.43 | val=0.005716✅ corr=0.9987❌ | 531s
# trial 0087 | reg_obj=poisson feat=top_300 w0=0.172 spw=2.43 | val=0.005721✅ corr=0.9984❌ | 556s
# trial 0088 | reg_obj=poisson feat=top_100 w0=0.187 spw=2.43 | val=0.005714✅ corr=0.9980❌ | 375s
# trial 0089 | reg_obj=poisson feat=top_100 w0=0.115 spw=2.43 | val=0.005728✅ corr=0.9949❌ | 393s
# trial 0090 | reg_obj=tweedie_1.5 feat=top_100 w0=0.187 spw=2.43 | val=0.005822✅ corr=0.9838❌ | 542s
# trial 0091 | reg_obj=poisson feat=top_100 w0=0.159 spw=1.5 | val=0.005726✅ corr=0.9983❌ | 354s
# trial 0092 | reg_obj=poisson feat=top_100 w0=0.191 spw=2.43 | val=0.005712✅ corr=0.9984❌ | 364s
# trial 0093 | reg_obj=poisson feat=top_100 w0=0.185 spw=2.43 | val=0.005713✅ corr=0.9984❌ | 381s
# trial 0094 | reg_obj=poisson feat=top_100 w0=0.174 spw=2.43 | val=0.005713✅ corr=0.9983❌ | 386s
# trial 0095 | reg_obj=poisson feat=top_100 w0=0.141 spw=2.43 | val=0.005719✅ corr=0.9981❌ | 362s
# trial 0096 | reg_obj=poisson feat=top_100 w0=0.177 spw=2.43 | val=0.005717✅ corr=0.9979❌ | 344s
# trial 0097 | reg_obj=tweedie_1.8 feat=top_100 w0=0.165 spw=2.43 | val=0.005754✅ corr=0.9890❌ | 444s
# trial 0098 | reg_obj=poisson feat=top_100 w0=0.190 spw=1.0 | val=0.005790✅ corr=0.9977❌ | 280s
# trial 0099 | reg_obj=regression feat=top_100 w0=0.157 spw=2.43 | val=0.005723✅ corr=0.9971❌ | 416s
# trial 0100 | reg_obj=poisson feat=top_100 w0=0.129 spw=2.43 | val=0.005720✅ corr=0.9970❌ | 387s
# trial 0101 | reg_obj=tweedie_1.3 feat=top_100 w0=0.173 spw=2.43 | val=0.005729✅ corr=0.9963❌ | 373s
# trial 0102 | reg_obj=poisson feat=top_100 w0=0.200 spw=2.43 | val=0.005713✅ corr=0.9988❌ | 365s
# trial 0103 | reg_obj=poisson feat=top_100 w0=0.192 spw=2.43 | val=0.005709✅ corr=0.9985❌ | 390s ★new_best
# trial 0104 | reg_obj=poisson feat=top_100 w0=0.203 spw=2.43 | val=0.005709✅ corr=0.9986❌ | 395s
# trial 0105 | reg_obj=poisson feat=top_100 w0=0.197 spw=2.43 | val=0.005713✅ corr=0.9983❌ | 402s
# trial 0106 | reg_obj=poisson feat=top_100 w0=0.209 spw=2.43 | val=0.005710✅ corr=0.9986❌ | 369s
# trial 0107 | reg_obj=tweedie_1.7 feat=top_100 w0=0.235 spw=2.43 | val=0.005763✅ corr=0.9893❌ | 474s
# trial 0108 | reg_obj=poisson feat=top_100 w0=0.201 spw=2.43 | val=0.005714✅ corr=0.9984❌ | 389s
# trial 0109 | reg_obj=poisson feat=top_100 w0=0.212 spw=2.43 | val=0.005718✅ corr=0.9973❌ | 409s
# trial 0110 | reg_obj=poisson feat=top_100 w0=0.232 spw=2.43 | val=0.005711✅ corr=0.9987❌ | 381s
# trial 0111 | reg_obj=poisson feat=top_100 w0=0.150 spw=2.43 | val=0.005720✅ corr=0.9983❌ | 360s
# trial 0112 | reg_obj=poisson feat=top_100 w0=0.229 spw=2.43 | val=0.005710✅ corr=0.9989❌ | 391s
# trial 0113 | reg_obj=poisson feat=top_100 w0=0.227 spw=2.43 | val=0.005709✅ corr=0.9988❌ | 390s
# trial 0114 | reg_obj=poisson feat=top_100 w0=0.241 spw=2.43 | val=0.005712✅ corr=0.9991❌ | 375s
# trial 0115 | reg_obj=poisson feat=top_100 w0=0.282 spw=2.43 | val=0.005717✅ corr=0.9989❌ | 374s
# trial 0116 | reg_obj=poisson feat=top_100 w0=0.230 spw=2.43 | val=0.005713✅ corr=0.9990❌ | 359s
# trial 0117 | reg_obj=tweedie_1.5 feat=top_100 w0=0.233 spw=2.43 | val=0.005727✅ corr=0.9952❌ | 409s
# trial 0118 | reg_obj=poisson feat=top_100 w0=0.253 spw=2.43 | val=0.005713✅ corr=0.9989❌ | 385s
# trial 0119 | reg_obj=poisson feat=top_100 w0=0.313 spw=1.5 | val=0.005774✅ corr=0.9979❌ | 380s
# trial 0120 | reg_obj=poisson feat=top_100 w0=0.242 spw=1.0 | val=0.005809✅ corr=0.9976❌ | 363s
# trial 0121 | reg_obj=tweedie_1.8 feat=top_100 w0=0.252 spw=2.43 | val=0.005766✅ corr=0.9896❌ | 489s
# trial 0122 | reg_obj=poisson feat=top_100 w0=0.225 spw=2.43 | val=0.005710✅ corr=0.9989❌ | 411s
# trial 0123 | reg_obj=poisson feat=top_100 w0=0.223 spw=2.43 | val=0.005711✅ corr=0.9991❌ | 358s
# trial 0124 | reg_obj=poisson feat=top_100 w0=0.229 spw=2.43 | val=0.005719✅ corr=0.9988❌ | 310s
# trial 0125 | reg_obj=poisson feat=top_100 w0=0.256 spw=2.43 | val=0.005715✅ corr=0.9990❌ | 368s
# trial 0126 | reg_obj=poisson feat=top_100 w0=0.259 spw=2.43 | val=0.005714✅ corr=0.9990❌ | 349s
# trial 0127 | reg_obj=poisson feat=top_100 w0=0.294 spw=2.43 | val=0.005721✅ corr=0.9989❌ | 355s
# trial 0128 | reg_obj=poisson feat=top_100 w0=0.270 spw=2.43 | val=0.005717✅ corr=0.9990❌ | 346s
# trial 0129 | reg_obj=regression feat=top_100 w0=0.255 spw=2.43 | val=0.005716✅ corr=0.9990❌ | 369s
# trial 0130 | reg_obj=tweedie_1.3 feat=top_100 w0=0.222 spw=2.43 | val=0.005717✅ corr=0.9983❌ | 368s
# trial 0131 | reg_obj=poisson feat=top_100 w0=0.276 spw=2.43 | val=0.005717✅ corr=0.9990❌ | 346s
# trial 0132 | reg_obj=regression feat=top_100 w0=0.247 spw=2.43 | val=0.005713✅ corr=0.9991❌ | 354s
# trial 0133 | reg_obj=regression feat=top_100 w0=0.241 spw=2.43 | val=0.005713✅ corr=0.9991❌ | 357s
# trial 0134 | reg_obj=regression feat=top_100 w0=0.253 spw=2.43 | val=0.005714✅ corr=0.9990❌ | 357s
# trial 0135 | reg_obj=regression feat=top_100 w0=0.321 spw=2.43 | val=0.005725✅ corr=0.9988❌ | 349s
# trial 0136 | reg_obj=regression feat=top_100 w0=0.235 spw=2.43 | val=0.005714✅ corr=0.9991❌ | 355s
# trial 0137 | reg_obj=regression feat=top_100 w0=0.245 spw=2.43 | val=0.005714✅ corr=0.9991❌ | 352s
# trial 0138 | reg_obj=regression feat=top_100 w0=0.234 spw=2.43 | val=0.005717✅ corr=0.9990❌ | 343s
# trial 0139 | reg_obj=regression feat=top_100 w0=0.222 spw=3.5 | val=0.005731✅ corr=0.9990❌ | 335s
# trial 0140 | reg_obj=regression feat=top_100 w0=0.244 spw=2.43 | val=0.005715✅ corr=0.9989❌ | 342s
# trial 0141 | reg_obj=regression feat=top_100 w0=0.238 spw=2.43 | val=0.005712✅ corr=0.9988❌ | 367s
# trial 0142 | reg_obj=regression feat=top_100 w0=0.241 spw=2.43 | val=0.005714✅ corr=0.9989❌ | 383s
# trial 0143 | reg_obj=regression feat=top_100 w0=0.242 spw=2.43 | val=0.005714✅ corr=0.9989❌ | 381s
# trial 0144 | reg_obj=regression feat=top_100 w0=0.278 spw=2.43 | val=0.005719✅ corr=0.9988❌ | 288s
# trial 0145 | reg_obj=regression feat=top_100 w0=0.299 spw=2.43 | val=0.005721✅ corr=0.9988❌ | 362s
# trial 0146 | reg_obj=regression feat=top_100 w0=0.965 spw=2.43 | val=0.005958✅ corr=0.9966❌ | 315s
# trial 0147 | reg_obj=regression feat=top_100 w0=0.217 spw=1.5 | val=0.005741✅ corr=0.9983❌ | 333s
# trial 0148 | reg_obj=regression feat=top_100 w0=0.244 spw=2.43 | val=0.005713✅ corr=0.9990❌ | 271s
# trial 0149 | reg_obj=regression feat=top_100 w0=0.361 spw=2.43 | val=0.005735✅ corr=0.9985❌ | 280s
# trial 0150 | reg_obj=regression feat=top_100 w0=0.223 spw=1.0 | val=0.005802✅ corr=0.9976❌ | 256s
# trial 0151 | reg_obj=regression feat=top_100 w0=0.263 spw=2.43 | val=0.005716✅ corr=0.9989❌ | 256s
# trial 0152 | reg_obj=regression feat=top_100 w0=0.240 spw=2.43 | val=0.005718✅ corr=0.9989❌ | 209s
# trial 0153 | reg_obj=regression feat=top_100 w0=0.244 spw=2.43 | val=0.005713✅ corr=0.9990❌ | 286s
# trial 0154 | reg_obj=regression feat=top_100 w0=0.288 spw=2.43 | val=0.005718✅ corr=0.9990❌ | 253s
#
# [HPO 종료] 65032s, completed trials: 155
# best OOF RMSE = 0.005500
# best params:
#   n_estimators              = 2073
#   learning_rate             = 0.005485943384271437
#   num_leaves                = 122
#   max_depth                 = 8
#   min_child_samples         = 192
#   subsample                 = 0.9264991368131481
#   colsample_bytree          = 0.915133968882927
#   reg_alpha                 = 2.2397781401234456
#   reg_lambda                = 5.018566966958517e-06
#   min_split_gain            = 0.2639626297328546
#   path_smooth               = 6.639254208373743
#   w0                        = 0.2254204377967333
#   reg_objective             = poisson
#   clf_scale_pos_weight      = 2.43
#   feat_subset               = top_100

# %% [markdown]
# ## 8. 전체 trial summary + 게이트 통과 후보 출력

# %%
# SQLite의 모든 trial info 추출 → summary.csv
rows = []
for t in study.trials:
    if t.state != optuna.trial.TrialState.COMPLETE:
        continue
    row = {
        'trial': t.number,
        'oof_rmse':        t.value,                              # objective return (= oof_rmse)
        'val_rmse':        t.user_attrs.get('val_rmse'),
        'test_rmse':       t.user_attrs.get('test_rmse'),
        'max_corr_11':     t.user_attrs.get('max_corr_vs_11base'),
        'n_feat_used':     t.user_attrs.get('n_feat_used'),
        'elapsed_s':       t.user_attrs.get('elapsed_s'),
        # axes
        **{f'param_{k}': v for k, v in t.params.items()},
    }
    row['pass_1'] = (row['val_rmse'] is not None) and (row['val_rmse'] < THR_SINGLE_VAL)
    row['pass_2'] = (row['max_corr_11'] is not None) and (row['max_corr_11'] < THR_CORR_VS_11)
    row['pre_pass'] = row['pass_1'] and row['pass_2']
    rows.append(row)

if len(rows) == 0:
    print('=== 완료된 trial 없음. SQLite에 FAIL 또는 RUNNING 상태만 있음 ===')
    n_fail = sum(1 for t in study.trials if t.state == optuna.trial.TrialState.FAIL)
    n_run  = sum(1 for t in study.trials if t.state == optuna.trial.TrialState.RUNNING)
    print(f'  FAIL: {n_fail} | RUNNING: {n_run} | total: {len(study.trials)}')
    summary_df = pd.DataFrame()
else:
    summary_df = pd.DataFrame(rows).sort_values('val_rmse')
    summary_df.to_csv(os.path.join(OUT_DIR, 'summary.csv'), index=False)

    print(f'=== 전체 complete trial: {len(summary_df)} ===')
    print(f'  게이트 1 (val<{THR_SINGLE_VAL:.6f}) 통과: {summary_df["pass_1"].sum()}')
    print(f'  게이트 2 (corr<{THR_CORR_VS_11}) 통과: {summary_df["pass_2"].sum()}')
    print(f'  둘 다 통과 (pre_pass): {summary_df["pre_pass"].sum()}')

    key_cols = ['trial','val_rmse','test_rmse','max_corr_11','pass_1','pass_2','pre_pass',
                'param_objective','param_target_transform','param_reg_objective','param_feat_subset','param_w0','param_clf_scale_pos_weight']
    display_cols = [c for c in key_cols if c in summary_df.columns]

    print(f'\n=== 상위 10 (val_rmse 기준) ===')
    print(summary_df.head(10)[display_cols].to_string(index=False))

    pass_df = summary_df[summary_df['pre_pass']]
    print(f'\n=== 게이트 통과 후보: {len(pass_df)}개 (있으면 best_*.csv 갱신과 별개 — 다양성 후보로 가치) ===')
    if len(pass_df) > 0:
        print(pass_df.head(30)[display_cols].to_string(index=False))
        print(f'\n⚠ 통과 trial이 best_val_rmse 아닌 경우, 그 trial의 OOF는 SQLite엔 메타만 있고 CSV 없음.')
        print(f'   필요 시 해당 HP로 재실행해서 CSV 받기. (요청 정책상 best 1개만 보관)')

# best_*.csv 파일 확인
print(f'\n=== best_*.csv 상태 (val_rmse={BEST_VAL_RMSE:.6f}) ===')
for fn in ['best_oof_unit.csv', 'best_val_unit.csv', 'best_test_unit.csv', 'best_meta.json']:
    p = os.path.join(OUT_DIR, fn)
    if os.path.exists(p):
        sz = os.path.getsize(p) / 1024
        print(f'  {fn:25s}  {sz:>8.1f} KB')
    else:
        print(f'  {fn:25s}  (없음)')

# Colab → 로컬 자동 다운로드
try:
    import google.colab
    from google.colab import files
    import shutil
    _zip_base = os.path.join('/content', os.path.basename(OUT_DIR) + '_outputs')
    _zip_path = shutil.make_archive(_zip_base, 'zip', OUT_DIR)
    print(f'\n[zip 생성] {_zip_path} ({os.path.getsize(_zip_path)/1024/1024:.1f} MB)')
    try:
        files.download(_zip_path)
    except Exception as _e:
        from IPython.display import FileLink, display
        print(f'[files.download 실패: {_e}] 아래 링크 클릭')
        display(FileLink(_zip_path))
except ImportError:
    pass
# Out:
# === 전체 complete trial: 154 ===
#   게이트 1 (val<0.005994) 통과: 152
#   게이트 2 (corr<0.97) 통과: 3
#   둘 다 통과 (pre_pass): 3
#
# === 상위 10 (val_rmse 기준) ===
#  trial  val_rmse  test_rmse  max_corr_11  pass_1  pass_2  pre_pass param_reg_objective param_feat_subset  param_w0  param_clf_scale_pos_weight
#    103  0.005709   0.008410     0.998480    True   False     False             poisson           top_100  0.192289                        2.43
#    104  0.005709   0.008410     0.998565    True   False     False             poisson           top_100  0.202624                        2.43
#    113  0.005709   0.008413     0.998804    True   False     False             poisson           top_100  0.227341                        2.43
#    122  0.005710   0.008412     0.998908    True   False     False             poisson           top_100  0.225420                        2.43
#    106  0.005710   0.008412     0.998586    True   False     False             poisson           top_100  0.209190                        2.43
#    112  0.005710   0.008413     0.998898    True   False     False             poisson           top_100  0.229311                        2.43
#    110  0.005711   0.008413     0.998708    True   False     False             poisson           top_100  0.231729                        2.43
#    123  0.005711   0.008413     0.999081    True   False     False             poisson           top_100  0.222592                        2.43
#    114  0.005712   0.008415     0.999069    True   False     False             poisson           top_100  0.240692                        2.43
#     83  0.005712   0.008413     0.999020    True   False     False             poisson           top_300  0.204375                        2.43
#
# === 게이트 통과 후보: 3개 (있으면 best_*.csv 갱신과 별개 — 다양성 후보로 가치) ===
#  trial  val_rmse  test_rmse  max_corr_11  pass_1  pass_2  pre_pass param_reg_objective param_feat_subset  param_w0  param_clf_scale_pos_weight
#     12  0.005888   0.008537     0.965199    True    True      True          regression           top_200  0.162331                         1.0
#     14  0.005929   0.008571     0.966606    True    True      True         tweedie_1.2           top_100  0.137630                         3.5
#     16  0.005933   0.008588     0.967438    True    True      True          regression           top_200  0.056488                         3.5
#
# ⚠ 통과 trial이 best_val_rmse 아닌 경우, 그 trial의 OOF는 SQLite엔 메타만 있고 CSV 없음.
#    필요 시 해당 HP로 재실행해서 CSV 받기. (요청 정책상 best 1개만 보관)
#
# === best_*.csv 상태 (val_rmse=0.005709) ===
#   best_oof_unit.csv             970.5 KB
#   best_val_unit.csv             323.4 KB
#   best_test_unit.csv            323.4 KB
#   best_meta.json                  0.9 KB
